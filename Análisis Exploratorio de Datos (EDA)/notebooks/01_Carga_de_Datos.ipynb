# %% [markdown]
# # **Objetivo**
# Conocer la estructura inicial del dataset.

# %% [markdown]
# # **Código**

# %%
import pandas as pd
df = pd.read_csv( "FAMILIAS_FOCALIZADAS.csv" )
print(df.shape)
df.head()
# Out:
# (5543, 22)
#   Bancarizado  CodigoDepartamentoAtencion  CodigoMunicipioAtencion  \
# 0          NO                          15                    15572
# 1          NO                          15                    15572
# 2          ND                          15                    15572
# 3          SI                          15                    15572
# 4          SI                          15                    15572
#
#   Discapacidad EstadoBeneficiario Etnia FechaInscripcionBeneficiario Genero  \
# 0           SI             ACTIVO    ND                   2012-12-01  Mujer
# 1           NO             ACTIVO    ND                   2013-08-01  Mujer
# 2           NO             ACTIVO    ND                   2015-09-01  Mujer
# 3           NO             ACTIVO    ND                   2012-12-01  Mujer
# 4           NO             ACTIVO    ND                   2012-12-01  Mujer
#
#   NivelEscolaridad NombreDepartamentoAtencion  ... TipoAsignacionBeneficio  \
# 0               ND                     BOYACA  ...                      ND
# 1         PRIMARIA                     BOYACA  ...                      ND
# 2               ND                     BOYACA  ...               MONETARIO
# 3               ND                     BOYACA  ...               MONETARIO
# 4               ND                     BOYACA  ...               MONETARIO
#
#         TipoBeneficio TipoDocumento TipoPoblacion  \
# 0                  ND            TI   DESPLAZADOS
# 1  EDUCACIÓN PRIMARIA            TI   DESPLAZADOS
# 2           NUTRICIÓN   No Definido   DESPLAZADOS
# 3                  ND            CC        UNIDOS
# 4                  ND            CC        UNIDOS
#
#   RangoBeneficioConsolidadoAsignado RangoUltimoBeneficioAsignado  \
# 0                     0 - 1.500.000                0 - 1.300.000
# 1                     0 - 1.500.000                0 - 1.300.000
# 2             3.000.001 - 4.500.000                0 - 1.300.000
# 3                     0 - 1.500.000                0 - 1.300.000
# 4                     0 - 1.500.000                0 - 1.300.000
#
#   FechaUltimoBeneficioAsignado RangoEdad Titular CantidadDeBeneficiarios
# 0                   1900-01-01     06-17      NO                       1
# 1                   1900-01-01     06-17      NO                       3
# 2                   2018-01-01     30-49      SI                       1
# 3                   2018-01-01       >65      SI                       1
# 4                   2018-01-01       >65      SI                       1
#
# [5 rows x 22 columns]

# %% [markdown]
# # **Preguntas**
#
# *   ¿Cuántas columnas tiene el dataset?
#     El dataset tiene **22 columnas**.
# *   ¿Qué variables contiene?
#     El dataset contiene las siguientes variables:
# >    `Bancarizado`, `CodigoDepartamentoAtencion`, `CodigoMunicipioAtencion`, `Discapacidad`, `EstadoBeneficiario`, `Etnia`, `FechaInscripcionBeneficiario`, `Genero`, `NivelEscolaridad`, `NombreDepartamentoAtencion`, `TipoAsignacionBeneficio`, `TipoBeneficio`, `TipoDocumento`, `TipoPoblacion`, `RangoBeneficioConsolidadoAsignado`, `RangoUltimoBeneficioAsignado`, `FechaUltimoBeneficioAsignado`, `RangoEdad`, `Titular`, `CantidadDeBeneficiarios`.
#
# *   ¿Cuántos registros existen?
#     El dataset contiene 5543 registros.
